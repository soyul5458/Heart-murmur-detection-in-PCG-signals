# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
data = pd.read_excel('/Users/leejungguk/project/20211217_HT_HUT_data_03.xlsx')

# %%
import os

ids = np.array([str1.split('.')[0] for str1 in os.listdir('/Users/leejungguk/project/HT/')], dtype = np.int32)

# %%
ids
# Out:
# array([ 956975,  941890,  685880, 1338151, 1314697,  915529, 1436276,
#         980333, 1442584,  768393,  990961, 1293860,  814542,  942227,
#         668589, 1294538, 1442531, 1028079], dtype=int32)

# %%
data.loc[data.Name == "김나연"]
# Out:
#        MRN Name Sex  Age dummy_start  dummy_end  HUTwithHT Holter_date  \
# 18  685880  김나연   F   56  2018-10-15 2019-07-12        1.0  2019-06-12
#
#    Holter_start_time Holter_duration  ... Group  Time_HUT_start_sec  \
# 18          11:34:00        22:25:00  ...   1.0             12720.0
#
#     Time_HUT_presyncope_sec  Time_HUT_syncope_sec  Time_HUT_end_sec   Dx  \
# 18                  14820.0               14940.0           15240.0  VVS
#
#    Cl_palpitation Cl_dizziness  Cl_syncope  HUT_syncope
# 18            1.0          1.0         1.0          1.0
#
# [1 rows x 31 columns]

# %%
data.iloc[18,:]
# Out:
# MRN                                     685880
# Name                                       김나연
# Sex                                          F
# Age                                         56
# dummy_start                2018-10-15 00:00:00
# dummy_end                  2019-07-12 00:00:00
# HUTwithHT                                  1.0
# Holter_date                2019-06-12 00:00:00
# Holter_start_time                     11:34:00
# Holter_duration                       22:25:00
# Holter_end_time                       09:59:00
# QRS_No                                 99288.0
# VPC_No                                    14.0
# APC_No                                     2.0
# VPC_run_No                                 NaN
# APC_run_No                                 NaN
# HUT_date                   2019-06-12 00:00:00
# HUT_start_time                        15:06:00
# HUT_presyncope_time                       35.0
# HUT_syncope_time                          37.0
# ...

# %%
d00685880 = pd.read_csv('/Users/leejungguk/project/HT/00685880.RAW_total_ch_test.csv', names=['C1','C2','C3', 'info'])
# Out:
# /Users/leejungguk/miniforge3/envs/new_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
d00685880.info(12)
#채널은 3개만 존재
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10087500 entries, 0 to 10087499
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   C1      float64
#  1   C2      float64
#  2   C3      float64
#  3   info    object
# dtypes: float64(3), object(1)
# memory usage: 307.8+ MB

# %%
data['MRN'].isin(ids)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 527    False
# 528    False
# 529    False
# 530    False
# 531    False
# Name: MRN, Length: 532, dtype: bool

# %%
subd=data.loc[data.MRN.isin(ids)]

# %%
subd
# Out:
#         MRN Name Sex  Age dummy_start  dummy_end  HUTwithHT Holter_date  \
# 2    668589  박덕임   F   62  2018-10-02 2019-06-29        0.0  2019-05-30
# 7   1436276   김단   F   23  2018-09-26 2019-06-23        0.0  2019-05-24
# 8    941890  박정숙   F   67  2018-10-02 2019-06-29        0.0  2019-05-30
# 9    768393  강성남   F   62  2018-11-24 2019-08-21        0.0  2019-07-22
# 10   956975  윤준학   M   57  2018-09-26 2019-06-23        0.0  2019-05-24
# 11  1314697  채정민   F   24  2018-10-15 2019-07-12        1.0  2019-06-12
# 12  1293860  박호정   M   27  2018-10-23 2019-07-20        1.0  2019-06-20
# 13   990961  류태성   M   84  2018-10-17 2019-07-14        0.0  2019-06-14
# 14   980333  이순금   F   59  2018-10-07 2019-07-04        0.0  2019-06-04
# 15  1338151  임규묵   M   79  2018-10-14 2019-07-11        0.0  2019-06-11
# 18   685880  김나연   F   56  2018-10-15 2019-07-12        1.0  2019-06-12
# 20   942227  최동영   M   65  2018-10-21 2019-07-18        0.0  2019-06-20
# ...

# %%
def to_integer(dt_time, freq=125):
  try :
    res = freq*int(dt_time)
  except :
    res = 0
  return res

# %%
HUT_start=to_integer(data.Time_HUT_start_sec[18])

# %%
HUT_event=to_integer(data.Time_HUT_syncope_sec[18])

# %%
HUT_end=to_integer(data.Time_HUT_end_sec[18])

# %%
partialD = d00685880.iloc[:,:3]

# %%
partialD.iloc[(125*15):(125*25) :].plot(kind = 'line', subplots=True, figsize=(20, 5))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
partialD.iloc[(HUT_start-125*5):(HUT_start+125*5) :].plot(kind = 'line', subplots=True, figsize=(20, 5))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
partialD.iloc[(HUT_event-125*5):(HUT_event+125*5) :].plot(kind = 'line', subplots=True, figsize=(20, 5))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
partialD.iloc[(HUT_end-125*20):(HUT_end-125*10) :].plot(kind = 'line', subplots=True, figsize=(20, 5))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
subd.loc[subd.MRN.isin([915529, 1442584, 1442531, 814542])]
# Out:
#         MRN Name Sex  Age dummy_start  dummy_end  HUTwithHT Holter_date  \
# 22   814542  송현설   M   79  2018-11-13 2019-08-10        1.0  2019-07-11
# 23  1442531  김경순   F   66  2018-11-19 2019-08-16        1.0  2019-07-17
# 24  1442584  김정구   M   42  2018-11-12 2019-08-09        0.0  2019-07-10
# 27   915529  이희영   F   34  2018-12-22 2019-09-18        1.0  2019-08-19
#
#    Holter_start_time Holter_duration  ... Group  Time_HUT_start_sec  \
# 22          13:29:00        23:51:00  ...   1.0              1440.0
# 23          11:34:00        22:06:00  ...   3.0             76860.0
# 24          16:34:00        23:19:00  ...   4.0                 NaN
# 27          15:56:00        23:19:00  ...   1.0               240.0
#
#     Time_HUT_presyncope_sec  Time_HUT_syncope_sec  Time_HUT_end_sec       Dx  \
# 22                   3540.0                3780.0            4020.0      VVS
# 23                      NaN                   NaN           79860.0  R/O VVS
# ...
